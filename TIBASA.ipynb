# %% [markdown]
# <a href="https://colab.research.google.com/github/davichomendez1901-byte/Simulaci-n/blob/main/TIBASA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# En este notebook se le dara solución al problema de tinas TIBASA planteado de la siguiente forma:
# La empresa TIBASA (Fabricante de tinas de baño) tiene asignado un camión especial para el transporte de tinas terminadas. Dicho camión transporta diariamente 5 tinas. El peso de cada tina sigue la distribución triangular de la imagen anexa.
#
# Si la capacidad del camión es de 1 tonelada, ¿cuál es la probabilidad de que el peso de las tinas exceda la capacidad del camión?

# %% [markdown]
# Dado que se transportan 5 tinas
# $$S = X_1, X_2, X_3, X_4, X_5$$
# El camión tiene una capacidad $$S>1000 kg$$ por lo tanto $$P(S>1000)$$

# %%
import numpy as np
import matplotlib.pyplot as plt
def triangular(a,b,c,n):
  lista = []
  for i in range(n):
    u = np.random.rand()
    F = (b-a)/(c-a)
    if u < F:
      x = a + np.sqrt(u*(b-a)*(c-a))
    else:
      x = c - np.sqrt((1-u)*(c-b)*(c-a))
    lista.append(x)
  return lista

# %%
R = triangular(190,210,250,10000)

plt.hist(R,bins=50)
plt.title('Distribución triangular')
plt.xlabel('Peso de las tinas')
plt.ylabel('Frecuencia')
plt.show()

# %%
N = 10000
excesos=0
S_vals=[]
for i in range (N):
  pesos=triangular(190,210,250,5)
  S=sum(pesos)
  S_vals.append(S)
  if S>1000:
    excesos+=1
prob = excesos/N
print("probabilidad",prob * 100)
# Out:
# probabilidad 99.96000000000001

# %%
plt.hist(S_vals,bins=50)
plt.title('Distribución de pesos de las tinas')
plt.xlabel('Peso de las tinas')
plt.ylabel('Frecuencia')
plt.show()
